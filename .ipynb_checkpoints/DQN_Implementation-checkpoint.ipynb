# %% [markdown]
# # DQN Implementation

# %% [markdown]
# ## Imports

# %%
import numpy as np
import time
from IPython.display import clear_output

import pickle

from envs import game2048_env

from tqdm import tqdm

from itertools import product

id_action_dict = {0 : "UP",
                  1 : "RIGHT",
                  2 : "DOWN",
                  3 : "LEFT"}

# %%
from torch import nn
import torch
from collections import deque
import itertools
import random
import torch.nn.functional as F

import matplotlib.pyplot as plt

# %%
if torch.cuda.is_available():
    device = "cuda:0"
elif torch.backends.mps.is_available():
    device = "mps" # "mps"
else:
    device = "cpu"
    
device = torch.device(device)
    
print("PyTorch is using :", device)
# Out:
# PyTorch is using : mps

# %% [markdown]
# ## Neural network

# %% [markdown]
# We first define the neural network architecture that we will use for the agent.

# %%
class DQN(nn.Module):
    ### Deep Q-Learning Network
    def __init__(self):
        super(DQN, self).__init__()
        
        input_depth = 11
        
        self.conv_a = nn.Conv2d(input_depth, 128, kernel_size=(1,2))       # Convolutional layers
        self.conv_b = nn.Conv2d(input_depth, 128, kernel_size=(2,1))

        self.conv_aa = nn.Conv2d(128, 128, kernel_size=(1,2))
        self.conv_ab = nn.Conv2d(128, 128, kernel_size=(2,1))

        self.conv_ba = nn.Conv2d(128, 128, kernel_size=(1,2))
        self.conv_bb = nn.Conv2d(128, 128, kernel_size=(2,1))
        
        self.fc = nn.Sequential(         # Linear and Relu
            nn.Linear(7424, 256),
            nn.ReLU(),
            nn.Linear(256, 4)
        )
        
    def forward(self, x):
        # Forward function of the layer
        x_a = F.relu(self.conv_a(x))
        x_b = F.relu(self.conv_b(x))
        
        x_aa = F.relu(self.conv_aa(x_a))
        x_ab = F.relu(self.conv_ab(x_a))
        
        x_ba = F.relu(self.conv_ba(x_b))
        x_bb = F.relu(self.conv_bb(x_b))
        
        sh_a = x_a.shape
        sh_aa = x_aa.shape
        sh_ab = x_ab.shape
        sh_b = x_b.shape
        sh_ba = x_ba.shape
        sh_bb = x_bb.shape
        
        x_a = x_a.view(sh_a[0],sh_a[1]*sh_a[2]*sh_a[3])
        x_aa = x_aa.view(sh_aa[0],sh_aa[1]*sh_aa[2]*sh_aa[3])
        x_ab = x_ab.view(sh_ab[0],sh_ab[1]*sh_ab[2]*sh_ab[3])
        x_b = x_b.view(sh_b[0],sh_b[1]*sh_b[2]*sh_b[3])
        x_ba = x_ba.view(sh_ba[0],sh_ba[1]*sh_ba[2]*sh_ba[3])
        x_bb = x_bb.view(sh_bb[0],sh_bb[1]*sh_bb[2]*sh_bb[3])
        
        concat = torch.cat((x_a,x_b,x_aa,x_ab,x_ba,x_bb),dim=1)
        
        output = self.fc(concat)
        
        return output
    
    def act(self, obs):
        obs_t = torch.as_tensor(obs, dtype=torch.float32)
        q_values = self(obs_t.unsqueeze(0))
        
        max_q_index = torch.argmax(q_values, dim=1)[0]
        
        action = max_q_index.detach().item()
        
        return action

# %% [markdown]
# ## Training

# %% [markdown]
# We then define a `class` for the agent, that will incorporate all the methods.

# %%
class DQN_Agent():
    def __init__(self,
                 gamma=0.99,
                 batch_size = 16,
                 buffer_size = 50000,
                 min_replay_size = 1000,
                 epsilon_start = 1,
                 epsilon_end = 0.0001,
                 epsilon_decay = 10000,
                 target_update_freq = 10,
                 learning_rate = 1e-4,
                 update_type="hard",
                 tau=0.001):
        
        self.GAMMA = gamma
        self.BATCH_SIZE = batch_size
        self.BUFFER_SIZE = buffer_size
        self.MIN_REPLAY_SIZE = min_replay_size
        self.EPSILON_START = epsilon_start
        self.EPSILON_END = epsilon_end
        self.EPSILON_DECAY = epsilon_decay
        
        self.epsilon = self.EPSILON_START
        
        self.step_count = 0
        
        self.TARGET_UPDATE_FREQ = 10
        self.update_type = update_type
        self.tau = tau
        
        self.LEARNING_RATE = learning_rate
        
        self.env = game2048_env.Game2048Env()
        
        self.replay_buffer = deque(maxlen=self.BUFFER_SIZE)
        self.rew_buffer = deque(maxlen=100)
        self.highest_buffer = deque(maxlen=100)
        
        if torch.cuda.is_available():
            device = "cuda"
        elif torch.backends.mps.is_available():
            device = "mps"
        else:
            device = "cpu"
        
        self.device = torch.device(device)
        
        
        self.online_net = DQN().to(device)
        self.target_net = DQN().to(device)
        
        self.target_net.load_state_dict(self.online_net.state_dict())
        
        self.optimizer = torch.optim.Adam(self.online_net.parameters(), lr=self.LEARNING_RATE)
        
        self.train_reward_history = []
        self.train_high_history = []
        self.train_loss_history = []

        self.play_high = 0

        self.train_play_high_history = []

    
    def _transform_observation(self, obs):
        obs = np.rollaxis(obs, 2)[:11]
        obs = np.flip(obs, axis=0)
        return obs.copy()
    
    def _transform_reward(self, obs, rew, info):
        
        #if info['illegal_move'] == True:
        #    rew = - 1
        
        #if rew > 0:
            #rew = rew
        
        # Number of full squares penalty
        rew = (16 - np.sum(obs)) / 2
        
        return rew
        
    
    def populate_buffer(self):
        obs = self.env.reset()
        obs = self._transform_observation(obs)
        
        for _ in range(self.MIN_REPLAY_SIZE):
            action = self.env.action_space.sample()

            new_obs, rew, done, info = self.env.step(action)
            rew = self._transform_reward(new_obs, rew, info)
            new_obs = self._transform_observation(new_obs)
            
            transition = (obs, action, rew, done, new_obs)
            self.replay_buffer.append(transition)
            obs = new_obs
    
            if done:
                obs = self.env.reset()
                obs = self._transform_observation(obs)
    
    def save_model(self):
        format = f"{self.update_type}_bs={self.BATCH_SIZE}_gamma={self.GAMMA}_lr={self.LEARNING_RATE}_eps={self.EPSILON_START}_decay={self.EPSILON_DECAY}"
        
        online_path = "online_" + format
        torch.save(self.online_net, online_path)
        
        target_path = "target_" + format
        torch.save(self.target_net, target_path)

        print("Format :\n")
        print(format)

        print("Model saved !")
        
    def load_model(self, path_format=None):

        if path_format is None:
            path_format = f"{self.update_type}_bs={self.BATCH_SIZE}_gamma={self.GAMMA}_lr={self.LEARNING_RATE}_eps={self.EPSILON_START}_decay={self.EPSILON_DECAY}"
        
        online_path = "online_" + path_format
        self.online_net = torch.load(online_path)
        
        target_path = "target_" + path_format
        self.target_net = torch.load(target_path)

        print("Model loaded !")
    
    
    def epoch(self):
        obs = self.env.reset()
        obs = self._transform_observation(obs)
        
        episode_reward = 0
        
        done = False
        
        
        while not done:
            
            self.step_count += 1
            
            
            # Epsilon Greedy Policy
            rnd_sample = np.random.random()
    
            if rnd_sample <= self.epsilon:
                action = self.env.action_space.sample()
                new_obs, rew, done, info = self.env.step(action)
                rew = self._transform_reward(new_obs, rew, info)
                new_obs = self._transform_observation(new_obs)
            else:
                obs_t = torch.as_tensor(obs, dtype=torch.float32).to(self.device)
                predicted_q_values = self.online_net.forward(obs_t.unsqueeze(0))
                
                best_performers = predicted_q_values.argsort()[0].cpu().numpy()[::-1]
                
                action = self.online_net.act(torch.as_tensor(obs, dtype=torch.float32).to(self.device))
                new_obs, rew, done, info = self.env.step(action)
                rew = self._transform_reward(new_obs, rew, info)
                new_obs = self._transform_observation(new_obs)
            
                if np.array_equal(new_obs, obs):
                    for action in best_performers[1:]:
                        # When the agent selects a move that can't change the state of the cells, so it loops infinitely
                        # We select an action other than the one corresponding to max-Q in Q-decreasing order
                        obs = new_obs
                        new_obs, rew, done, info = self.env.step(action)
                        rew = self._transform_reward(new_obs, rew, info)
                        new_obs = self._transform_observation(new_obs)

                        if not np.array_equal(new_obs, obs):
                            break
            
            
            transition = (obs, action, rew, done, new_obs)
            obs = new_obs
            
            #print(obs.shape)
            
            self.replay_buffer.append(transition)
            
            episode_reward += rew
            
            # Update Target Network
            if (self.update_type == "hard") and (self.step_count % self.TARGET_UPDATE_FREQ == 0):
                self.target_net.load_state_dict(self.online_net.state_dict())
            elif self.update_type == "soft":
                target_net_state_dict = self.target_net.state_dict()
                online_net_state_dict = self.online_net.state_dict()
                for key in online_net_state_dict:
                    target_net_state_dict[key] = online_net_state_dict[key] * self.tau + target_net_state_dict[key]*(1-self.tau)
                self.target_net.load_state_dict(target_net_state_dict)
            
            
            if self.step_count % 1 == 0:
                # Start Gradient Step
                transitions = random.sample(self.replay_buffer, self.BATCH_SIZE)

                obses = np.asarray([t[0] for t in transitions])
                actions = np.asarray([t[1] for t in transitions])
                rews = np.asarray([t[2] for t in transitions])
                dones = np.asarray([t[3] for t in transitions])
                new_obses = np.asarray([t[4] for t in transitions])

                obses_t = torch.as_tensor(obses, dtype=torch.float32).squeeze(1).to(self.device)
                actions_t = torch.as_tensor(actions, dtype=torch.int64).unsqueeze(1).to(self.device)
                rews_t = torch.as_tensor(rews, dtype=torch.float32).unsqueeze(1).to(self.device)
                dones_t = torch.as_tensor(dones, dtype=torch.float32).unsqueeze(1).to(self.device)
                new_obses_t = torch.as_tensor(new_obses, dtype=torch.float32).squeeze(1).to(self.device)

                # Compute targets
                with torch.no_grad():
                    target_q_values = self.target_net(new_obses_t)
                    max_target_q_values = target_q_values.max(dim=1, keepdim=True)[0]

                targets = rews_t + self.GAMMA * (1 - dones_t) * max_target_q_values

                # Compute Loss
                q_values = self.online_net(obses_t)

                action_q_values = torch.gather(input=q_values, dim=1, index=actions_t)

                loss = nn.functional.mse_loss(action_q_values, targets)
                
                # Gradient Descent
                self.optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_value_(self.online_net.parameters(), 100)   # Gradient clipping
                self.optimizer.step()
            
            self.train_loss_history.append(loss.detach().cpu().numpy().item())


            if done:
                obs = self.env.reset()
                obs = self._transform_observation(obs)

                self.rew_buffer.append(episode_reward)
                self.highest_buffer.append(info['highest'])
                
                #print("Epsilon :", self.epsilon)

        epsilon_step = (self.EPSILON_START - self.EPSILON_END) / self.EPSILON_DECAY
        self.epsilon = max(self.epsilon - epsilon_step, self.EPSILON_END)
    
        #print(self.epsilon)
            
        return episode_reward, info['highest'], loss.detach().cpu().numpy().item()
            
    
    def train(self, n_epochs, verbose=True, save_model=True, play_epoch=100):
        
        if len(self.replay_buffer) < self.MIN_REPLAY_SIZE:
            if verbose:
                print("Filling the buffer...")
            self.populate_buffer()
        
        if verbose:
            print("Start training")
            print("-" * 100)
        
        reward_history = []
        high_history = []
        loss_history = []
        
        for epoch in tqdm(range(n_epochs), disable=True):
            rew_buffer, highest_buffer, loss = self.epoch()
            
            loss_history.append(loss)
            
            avg_rew = int(np.mean(rew_buffer))
            avg_high = int(np.mean(highest_buffer))
            avg_loss = np.round(np.mean(loss), 1)
            
            self.train_reward_history.append(avg_rew)
            self.train_high_history.append(avg_high)

            if verbose:
                print(f"Epoch {epoch+1}/{n_epochs} : reward = {avg_rew}, highest value = {avg_high}")

            if (epoch + 1) % play_epoch == 0: 
                average_high_play = 0
                average_high_play_log = 0
                n_plays = 20
                for _ in range(n_plays):
                    self = self.play(False)
                    average_high_play_log += np.log2(self.play_high) / n_plays
                    average_high_play += self.play_high / n_plays
                
                self.train_play_high_history.append(average_high_play)

                print("-" * 70)
                print("Average of log2(high) while playing :", np.round(average_high_play_log, 2))
                print("Average of high while playing :", np.round(average_high_play, 1))
                print("-" * 70)
        
        print('_' * 100)
        print("Training ended !")
        print('_' * 100)

        if save_model:
            self.save_model()
        
        return agent
            
    
    def play(self, render=True):
        
        obs = self.env.reset()
        obs = self._transform_observation(obs)
        
        self.play_high = 0
        
        done = False
        
        while not done:
            obs_t = torch.as_tensor(obs, dtype=torch.float32).to(self.device)
            predicted_q_values = self.online_net.forward(obs_t.unsqueeze(0))

            best_performers = predicted_q_values.argsort()[0].cpu().numpy()[::-1]

            action = self.online_net.act(torch.as_tensor(obs, dtype=torch.float32).to(self.device))
            new_obs, rew, done, info = self.env.step(action)
            #rew = self._transform_reward(new_obs, rew)
            new_obs = self._transform_observation(new_obs)
                

            if np.array_equal(new_obs, obs):
                for action in best_performers[1:]:
                    # When the agent selects a move that can't change the state of the cells, so it loops infinitely
                    # We select an action other than the one corresponding to max-Q in Q-decreasing order
                    obs = new_obs
                    new_obs, rew, done, info = self.env.step(action)
                    rew = self._transform_reward(new_obs, rew, info)
                    new_obs = self._transform_observation(new_obs)

                    if not np.array_equal(new_obs, obs):
                        break
            else:
                obs = new_obs
            
            if render:
                clear_output(wait=True)
                
                self.env.render('human')
            
            if done:
                self.play_high = info["highest"]
        
        return self

# %% [markdown]
# ### Hyperparameter tuning

# %%
batch_size_values = [32]
epsilon_start_values = [0.1, 0.3]
epsilon_decay_values = [600]
update_type_values = ['hard', 'soft']

tau_values = [0.01, 0.001, 0.005]
target_update_freq_values = [5, 10, 20]

combinations = product(batch_size_values,
                       epsilon_start_values,
                       epsilon_decay_values,
                       update_type_values)

combinations = list(combinations)

n_train_episodes = 500

n_total = len(list(combinations)) * 3

i = 0

dict_agents = dict()


for combination in combinations:
    batch_size, epsilon_start, epsilon_decay, update_type = combination

    if update_type == 'soft':
        for tau in tau_values:
            i += 1
            print(f"Combination {i} / {n_total} :")
            print(combination)
            print("tau =", tau)
            agent = DQN_Agent(gamma=gamma,
                            batch_size=batch_size,
                            buffer_size=buffer_size,
                            min_replay_size=min_replay_size,
                            epsilon_start=epsilon_start,
                            epsilon_end=epsilon_end,
                            epsilon_decay=epsilon_decay,
                            target_update_freq=target_update_freq,
                            learning_rate=learning_rate,
                            update_type=update_type,
                            tau=tau)
            
            agent = agent.train(n_train_episodes, verbose=False, save_model=False, play_epoch=n_train_episodes)

            list_combi = list(combination)
            dict_key = list_combi + [tau]
            dict_agents[dict_key] = agent

            print("-" * 70)

            
    if update_type == 'hard':
        for target_update_freq in target_update_freq_values:
            i += 1
            print(f"Combination {i} / {n_total} :")
            print(combination)
            print("target_update_fred =", target_update_freq)
            agent = DQN_Agent(gamma=gamma,
                            batch_size=batch_size,
                            buffer_size=buffer_size,
                            min_replay_size=min_replay_size,
                            epsilon_start=epsilon_start,
                            epsilon_end=epsilon_end,
                            epsilon_decay=epsilon_decay,
                            target_update_freq=target_update_freq,
                            learning_rate=learning_rate,
                            update_type=update_type,
                            tau=tau)
            
            agent = agent.train(n_train_episodes, verbose=False, save_model=False, play_epoch=n_train_episodes)

            list_combi = list(combination)
            dict_key = list_combi + [target_update_freq]
            dict_agents[dict_key] = agent

            print("-" * 70)

# %%
with open('dict_agents_hyperparameter.pickle', 'wb') as file:
    pickle.dump(dict_agents, file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# The combination that was the best on the first 500 epochs was BY FAR :
#
# (32, 0.3, 600, 'soft') with tau = 0.001
#
# We will therefore use it in the subsequent training.

# %% [markdown]
# Let's first plot the rewards and the scores for the hyperparameter combinations :

# %%
with open('dict_agents_hyperparameter.pickle', 'rb') as file:
    dict_test = pickle.load(file)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Training the agent

# %% [markdown]
# We now train the model on the following parameters and see how it performs :

# %%
gamma = 0.99
batch_size = 64
buffer_size = 100000
min_replay_size = batch_size * 10
epsilon_start = 0.2
epsilon_end = 1e-3
epsilon_decay = 750
target_update_freq = 50
learning_rate = 1e-4
update_type = "soft"
tau = 1e-3


agent = DQN_Agent(gamma=gamma,
                  batch_size=batch_size,
                  buffer_size=buffer_size,
                  min_replay_size=min_replay_size,
                  epsilon_start=epsilon_start,
                  epsilon_end=epsilon_end,
                  epsilon_decay=epsilon_decay,
                  target_update_freq=target_update_freq,
                  learning_rate=learning_rate,
                  update_type=update_type,
                  tau=tau)

# %%
n_training_episodes = 2900

agent.train(n_training_episodes)
# Out:
# Filling the buffer...
# Start training
# ----------------------------------------------------------------------------------------------------
# Epoch 1/2900 : reward = 308, highest value = 64
# Epoch 2/2900 : reward = 245, highest value = 64
# Epoch 3/2900 : reward = 344, highest value = 128
# Epoch 4/2900 : reward = 332, highest value = 128
# Epoch 5/2900 : reward = 346, highest value = 256
# Epoch 6/2900 : reward = 416, highest value = 128
# Epoch 7/2900 : reward = 264, highest value = 64
# Epoch 8/2900 : reward = 281, highest value = 128
# Epoch 9/2900 : reward = 360, highest value = 128
# Epoch 10/2900 : reward = 307, highest value = 128
# Epoch 11/2900 : reward = 338, highest value = 128
# Epoch 12/2900 : reward = 344, highest value = 128
# Epoch 13/2900 : reward = 446, highest value = 128
# Epoch 14/2900 : reward = 278, highest value = 64
# Epoch 15/2900 : reward = 371, highest value = 128
# Epoch 16/2900 : reward = 410, highest value = 128
# Epoch 17/2900 : reward = 411, highest value = 256
# Epoch 18/2900 : reward = 309, highest value = 64
# Epoch 19/2900 : reward = 521, highest value = 256
# Epoch 20/2900 : reward = 410, highest value = 256
# Epoch 21/2900 : reward = 231, highest value = 64
# Epoch 22/2900 : reward = 444, highest value = 128
# Epoch 23/2900 : reward = 419, highest value = 128
# Epoch 24/2900 : reward = 497, highest value = 256
# Epoch 25/2900 : reward = 616, highest value = 512
# Epoch 26/2900 : reward = 270, highest value = 64
# Epoch 27/2900 : reward = 599, highest value = 256
# Epoch 28/2900 : reward = 418, highest value = 128
# Epoch 29/2900 : reward = 375, highest value = 128
# Epoch 30/2900 : reward = 406, highest value = 128
# Epoch 31/2900 : reward = 297, highest value = 64
# Epoch 32/2900 : reward = 457, highest value = 256
# Epoch 33/2900 : reward = 467, highest value = 128
# Epoch 34/2900 : reward = 610, highest value = 256
# Epoch 35/2900 : reward = 354, highest value = 128
# Epoch 36/2900 : reward = 325, highest value = 64
# Epoch 37/2900 : reward = 311, highest value = 128
# Epoch 38/2900 : reward = 624, highest value = 256
# Epoch 39/2900 : reward = 496, highest value = 256
# Epoch 40/2900 : reward = 635, highest value = 256
# Epoch 41/2900 : reward = 366, highest value = 64
# Epoch 42/2900 : reward = 375, highest value = 128
# Epoch 43/2900 : reward = 449, highest value = 128
# Epoch 44/2900 : reward = 547, highest value = 256
# Epoch 45/2900 : reward = 685, highest value = 256
# Epoch 46/2900 : reward = 405, highest value = 128
# Epoch 47/2900 : reward = 516, highest value = 128
# Epoch 48/2900 : reward = 638, highest value = 256
# Epoch 49/2900 : reward = 494, highest value = 128
# Epoch 50/2900 : reward = 485, highest value = 128
# Epoch 51/2900 : reward = 279, highest value = 64
# Epoch 52/2900 : reward = 426, highest value = 128
# Epoch 53/2900 : reward = 413, highest value = 128
# Epoch 54/2900 : reward = 524, highest value = 256
# Epoch 55/2900 : reward = 454, highest value = 128
# Epoch 56/2900 : reward = 450, highest value = 128
# Epoch 57/2900 : reward = 421, highest value = 128
# Epoch 58/2900 : reward = 382, highest value = 128
# Epoch 59/2900 : reward = 496, highest value = 256
# Epoch 60/2900 : reward = 599, highest value = 256
# Epoch 61/2900 : reward = 474, highest value = 256
# Epoch 62/2900 : reward = 321, highest value = 64
# Epoch 63/2900 : reward = 617, highest value = 256
# Epoch 64/2900 : reward = 451, highest value = 128
# Epoch 65/2900 : reward = 477, highest value = 256
# Epoch 66/2900 : reward = 431, highest value = 128
# Epoch 67/2900 : reward = 491, highest value = 128
# Epoch 68/2900 : reward = 610, highest value = 256
# Epoch 69/2900 : reward = 309, highest value = 64
# Epoch 70/2900 : reward = 469, highest value = 128
# Epoch 71/2900 : reward = 440, highest value = 128
# Epoch 72/2900 : reward = 486, highest value = 128
# Epoch 73/2900 : reward = 483, highest value = 128
# Epoch 74/2900 : reward = 462, highest value = 128
# Epoch 75/2900 : reward = 744, highest value = 256
# Epoch 76/2900 : reward = 589, highest value = 256
# Epoch 77/2900 : reward = 318, highest value = 128
# Epoch 78/2900 : reward = 581, highest value = 256
# Epoch 79/2900 : reward = 464, highest value = 256
# Epoch 80/2900 : reward = 491, highest value = 256
# Epoch 81/2900 : reward = 516, highest value = 256
# Epoch 82/2900 : reward = 527, highest value = 256
# Epoch 83/2900 : reward = 497, highest value = 256
# Epoch 84/2900 : reward = 417, highest value = 128
# Epoch 85/2900 : reward = 407, highest value = 128
# Epoch 86/2900 : reward = 437, highest value = 128
# Epoch 87/2900 : reward = 408, highest value = 128
# Epoch 88/2900 : reward = 756, highest value = 512
# Epoch 89/2900 : reward = 386, highest value = 128
# Epoch 90/2900 : reward = 532, highest value = 256
# Epoch 91/2900 : reward = 328, highest value = 64
# Epoch 92/2900 : reward = 490, highest value = 128
# Epoch 93/2900 : reward = 436, highest value = 128
# Epoch 94/2900 : reward = 588, highest value = 256
# Epoch 95/2900 : reward = 632, highest value = 256
# Epoch 96/2900 : reward = 408, highest value = 128
# Epoch 97/2900 : reward = 747, highest value = 256
# Epoch 98/2900 : reward = 416, highest value = 128
# Epoch 99/2900 : reward = 599, highest value = 256
# Epoch 100/2900 : reward = 318, highest value = 64
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 7.4
# Average of high while playing : 195.2
# ----------------------------------------------------------------------
# Epoch 101/2900 : reward = 517, highest value = 256
# Epoch 102/2900 : reward = 650, highest value = 256
# Epoch 103/2900 : reward = 598, highest value = 256
# Epoch 104/2900 : reward = 473, highest value = 128
# Epoch 105/2900 : reward = 789, highest value = 512
# Epoch 106/2900 : reward = 460, highest value = 128
# Epoch 107/2900 : reward = 564, highest value = 256
# Epoch 108/2900 : reward = 299, highest value = 64
# Epoch 109/2900 : reward = 289, highest value = 64
# Epoch 110/2900 : reward = 624, highest value = 256
# Epoch 111/2900 : reward = 746, highest value = 512
# Epoch 112/2900 : reward = 617, highest value = 256
# Epoch 113/2900 : reward = 543, highest value = 256
# Epoch 114/2900 : reward = 526, highest value = 256
# Epoch 115/2900 : reward = 634, highest value = 256
# Epoch 116/2900 : reward = 567, highest value = 256
# Epoch 117/2900 : reward = 506, highest value = 256
# Epoch 118/2900 : reward = 585, highest value = 256
# Epoch 119/2900 : reward = 554, highest value = 128
# Epoch 120/2900 : reward = 396, highest value = 128
# Epoch 121/2900 : reward = 520, highest value = 256
# Epoch 122/2900 : reward = 627, highest value = 256
# Epoch 123/2900 : reward = 405, highest value = 128
# Epoch 124/2900 : reward = 465, highest value = 128
# Epoch 125/2900 : reward = 413, highest value = 128
# Epoch 126/2900 : reward = 537, highest value = 256
# Epoch 127/2900 : reward = 958, highest value = 512
# Epoch 128/2900 : reward = 450, highest value = 128
# Epoch 129/2900 : reward = 516, highest value = 128
# Epoch 130/2900 : reward = 432, highest value = 128
# Epoch 131/2900 : reward = 773, highest value = 512
# Epoch 132/2900 : reward = 570, highest value = 256
# Epoch 133/2900 : reward = 666, highest value = 256
# Epoch 134/2900 : reward = 472, highest value = 256
# Epoch 135/2900 : reward = 578, highest value = 256
# Epoch 136/2900 : reward = 533, highest value = 256
# Epoch 137/2900 : reward = 326, highest value = 64
# Epoch 138/2900 : reward = 382, highest value = 128
# Epoch 139/2900 : reward = 376, highest value = 64
# Epoch 140/2900 : reward = 612, highest value = 256
# Epoch 141/2900 : reward = 496, highest value = 128
# Epoch 142/2900 : reward = 714, highest value = 512
# Epoch 143/2900 : reward = 674, highest value = 256
# Epoch 144/2900 : reward = 674, highest value = 256
# Epoch 145/2900 : reward = 842, highest value = 512
# Epoch 146/2900 : reward = 666, highest value = 256
# Epoch 147/2900 : reward = 655, highest value = 256
# Epoch 148/2900 : reward = 646, highest value = 256
# Epoch 149/2900 : reward = 301, highest value = 64
# Epoch 150/2900 : reward = 442, highest value = 128
# Epoch 151/2900 : reward = 405, highest value = 128
# Epoch 152/2900 : reward = 712, highest value = 256
# Epoch 153/2900 : reward = 679, highest value = 256
# Epoch 154/2900 : reward = 524, highest value = 256
# Epoch 155/2900 : reward = 333, highest value = 64
# Epoch 156/2900 : reward = 486, highest value = 256
# Epoch 157/2900 : reward = 580, highest value = 256
# Epoch 158/2900 : reward = 538, highest value = 256
# Epoch 159/2900 : reward = 504, highest value = 128
# Epoch 160/2900 : reward = 487, highest value = 256
# Epoch 161/2900 : reward = 463, highest value = 128
# Epoch 162/2900 : reward = 689, highest value = 256
# Epoch 163/2900 : reward = 457, highest value = 128
# Epoch 164/2900 : reward = 603, highest value = 256
# Epoch 165/2900 : reward = 494, highest value = 128
# Epoch 166/2900 : reward = 826, highest value = 512
# Epoch 167/2900 : reward = 387, highest value = 128
# Epoch 168/2900 : reward = 763, highest value = 256
# Epoch 169/2900 : reward = 936, highest value = 512
# Epoch 170/2900 : reward = 282, highest value = 64
# Epoch 171/2900 : reward = 509, highest value = 128
# Epoch 172/2900 : reward = 782, highest value = 256
# Epoch 173/2900 : reward = 353, highest value = 128
# Epoch 174/2900 : reward = 609, highest value = 256
# Epoch 175/2900 : reward = 455, highest value = 128
# Epoch 176/2900 : reward = 505, highest value = 256
# Epoch 177/2900 : reward = 574, highest value = 256
# Epoch 178/2900 : reward = 599, highest value = 256
# Epoch 179/2900 : reward = 573, highest value = 256
# Epoch 180/2900 : reward = 627, highest value = 256
# Epoch 181/2900 : reward = 488, highest value = 128
# Epoch 182/2900 : reward = 526, highest value = 256
# Epoch 183/2900 : reward = 428, highest value = 128
# Epoch 184/2900 : reward = 433, highest value = 128
# Epoch 185/2900 : reward = 282, highest value = 64
# Epoch 186/2900 : reward = 565, highest value = 256
# Epoch 187/2900 : reward = 349, highest value = 128
# Epoch 188/2900 : reward = 692, highest value = 256
# Epoch 189/2900 : reward = 465, highest value = 128
# Epoch 190/2900 : reward = 683, highest value = 256
# Epoch 191/2900 : reward = 692, highest value = 512
# Epoch 192/2900 : reward = 440, highest value = 128
# Epoch 193/2900 : reward = 368, highest value = 128
# Epoch 194/2900 : reward = 674, highest value = 256
# Epoch 195/2900 : reward = 598, highest value = 256
# Epoch 196/2900 : reward = 628, highest value = 256
# Epoch 197/2900 : reward = 640, highest value = 256
# Epoch 198/2900 : reward = 425, highest value = 128
# Epoch 199/2900 : reward = 703, highest value = 512
# Epoch 200/2900 : reward = 612, highest value = 256
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 7.35
# Average of high while playing : 179.2
# ----------------------------------------------------------------------
# Epoch 201/2900 : reward = 721, highest value = 256
# Epoch 202/2900 : reward = 487, highest value = 256
# Epoch 203/2900 : reward = 617, highest value = 256
# Epoch 204/2900 : reward = 740, highest value = 512
# Epoch 205/2900 : reward = 457, highest value = 128
# Epoch 206/2900 : reward = 635, highest value = 256
# Epoch 207/2900 : reward = 432, highest value = 128
# Epoch 208/2900 : reward = 625, highest value = 256
# Epoch 209/2900 : reward = 640, highest value = 256
# Epoch 210/2900 : reward = 408, highest value = 128
# Epoch 211/2900 : reward = 475, highest value = 128
# Epoch 212/2900 : reward = 552, highest value = 128
# Epoch 213/2900 : reward = 668, highest value = 256
# Epoch 214/2900 : reward = 512, highest value = 256
# Epoch 215/2900 : reward = 852, highest value = 512
# Epoch 216/2900 : reward = 589, highest value = 256
# Epoch 217/2900 : reward = 603, highest value = 256
# Epoch 218/2900 : reward = 563, highest value = 256
# Epoch 219/2900 : reward = 419, highest value = 128
# Epoch 220/2900 : reward = 475, highest value = 128
# Epoch 221/2900 : reward = 567, highest value = 256
# Epoch 222/2900 : reward = 588, highest value = 256
# Epoch 223/2900 : reward = 594, highest value = 256
# Epoch 224/2900 : reward = 714, highest value = 256
# Epoch 225/2900 : reward = 618, highest value = 256
# Epoch 226/2900 : reward = 403, highest value = 128
# Epoch 227/2900 : reward = 425, highest value = 128
# Epoch 228/2900 : reward = 559, highest value = 256
# Epoch 229/2900 : reward = 641, highest value = 256
# Epoch 230/2900 : reward = 679, highest value = 256
# Epoch 231/2900 : reward = 688, highest value = 512
# Epoch 232/2900 : reward = 430, highest value = 128
# Epoch 233/2900 : reward = 510, highest value = 128
# Epoch 234/2900 : reward = 735, highest value = 256
# Epoch 235/2900 : reward = 346, highest value = 128
# Epoch 236/2900 : reward = 656, highest value = 256
# Epoch 237/2900 : reward = 601, highest value = 256
# Epoch 238/2900 : reward = 279, highest value = 64
# Epoch 239/2900 : reward = 619, highest value = 256
# Epoch 240/2900 : reward = 599, highest value = 256
# Epoch 241/2900 : reward = 572, highest value = 256
# Epoch 242/2900 : reward = 804, highest value = 512
# Epoch 243/2900 : reward = 215, highest value = 64
# Epoch 244/2900 : reward = 384, highest value = 128
# Epoch 245/2900 : reward = 475, highest value = 256
# Epoch 246/2900 : reward = 543, highest value = 256
# Epoch 247/2900 : reward = 781, highest value = 512
# Epoch 248/2900 : reward = 459, highest value = 128
# Epoch 249/2900 : reward = 467, highest value = 128
# Epoch 250/2900 : reward = 760, highest value = 512
# Epoch 251/2900 : reward = 815, highest value = 512
# Epoch 252/2900 : reward = 493, highest value = 128
# Epoch 253/2900 : reward = 454, highest value = 128
# Epoch 254/2900 : reward = 483, highest value = 256
# Epoch 255/2900 : reward = 622, highest value = 256
# Epoch 256/2900 : reward = 574, highest value = 256
# Epoch 257/2900 : reward = 672, highest value = 256
# Epoch 258/2900 : reward = 346, highest value = 128
# Epoch 259/2900 : reward = 557, highest value = 256
# Epoch 260/2900 : reward = 591, highest value = 256
# Epoch 261/2900 : reward = 914, highest value = 512
# Epoch 262/2900 : reward = 876, highest value = 512
# Epoch 263/2900 : reward = 297, highest value = 64
# Epoch 264/2900 : reward = 441, highest value = 128
# Epoch 265/2900 : reward = 604, highest value = 256
# Epoch 266/2900 : reward = 465, highest value = 128
# Epoch 267/2900 : reward = 726, highest value = 256
# Epoch 268/2900 : reward = 760, highest value = 256
# Epoch 269/2900 : reward = 325, highest value = 64
# Epoch 270/2900 : reward = 558, highest value = 128
# Epoch 271/2900 : reward = 791, highest value = 512
# Epoch 272/2900 : reward = 655, highest value = 256
# Epoch 273/2900 : reward = 986, highest value = 512
# Epoch 274/2900 : reward = 708, highest value = 256
# Epoch 275/2900 : reward = 450, highest value = 128
# Epoch 276/2900 : reward = 440, highest value = 128
# Epoch 277/2900 : reward = 661, highest value = 256
# Epoch 278/2900 : reward = 643, highest value = 256
# Epoch 279/2900 : reward = 532, highest value = 256
# Epoch 280/2900 : reward = 674, highest value = 256
# Epoch 281/2900 : reward = 438, highest value = 256
# Epoch 282/2900 : reward = 701, highest value = 256
# Epoch 283/2900 : reward = 598, highest value = 256
# Epoch 284/2900 : reward = 526, highest value = 256
# Epoch 285/2900 : reward = 440, highest value = 128
# Epoch 286/2900 : reward = 1038, highest value = 512
# Epoch 287/2900 : reward = 633, highest value = 256
# Epoch 288/2900 : reward = 481, highest value = 128
# Epoch 289/2900 : reward = 416, highest value = 128
# Epoch 290/2900 : reward = 513, highest value = 256
# Epoch 291/2900 : reward = 564, highest value = 256
# Epoch 292/2900 : reward = 628, highest value = 256
# Epoch 293/2900 : reward = 755, highest value = 512
# Epoch 294/2900 : reward = 911, highest value = 512
# Epoch 295/2900 : reward = 725, highest value = 256
# Epoch 296/2900 : reward = 496, highest value = 128
# Epoch 297/2900 : reward = 317, highest value = 64
# Epoch 298/2900 : reward = 540, highest value = 256
# Epoch 299/2900 : reward = 613, highest value = 256
# Epoch 300/2900 : reward = 540, highest value = 256
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 7.65
# Average of high while playing : 240.0
# ----------------------------------------------------------------------
# Epoch 301/2900 : reward = 608, highest value = 256
# Epoch 302/2900 : reward = 478, highest value = 256
# Epoch 303/2900 : reward = 865, highest value = 512
# Epoch 304/2900 : reward = 677, highest value = 256
# Epoch 305/2900 : reward = 454, highest value = 128
# Epoch 306/2900 : reward = 618, highest value = 256
# Epoch 307/2900 : reward = 483, highest value = 128
# Epoch 308/2900 : reward = 474, highest value = 128
# Epoch 309/2900 : reward = 695, highest value = 256
# Epoch 310/2900 : reward = 717, highest value = 256
# Epoch 311/2900 : reward = 848, highest value = 512
# Epoch 312/2900 : reward = 609, highest value = 256
# Epoch 313/2900 : reward = 425, highest value = 128
# Epoch 314/2900 : reward = 321, highest value = 64
# Epoch 315/2900 : reward = 431, highest value = 128
# Epoch 316/2900 : reward = 644, highest value = 256
# Epoch 317/2900 : reward = 723, highest value = 256
# Epoch 318/2900 : reward = 648, highest value = 256
# Epoch 319/2900 : reward = 542, highest value = 256
# Epoch 320/2900 : reward = 428, highest value = 128
# Epoch 321/2900 : reward = 442, highest value = 128
# Epoch 322/2900 : reward = 537, highest value = 256
# Epoch 323/2900 : reward = 730, highest value = 256
# Epoch 324/2900 : reward = 612, highest value = 256
# Epoch 325/2900 : reward = 409, highest value = 128
# Epoch 326/2900 : reward = 749, highest value = 256
# Epoch 327/2900 : reward = 432, highest value = 128
# Epoch 328/2900 : reward = 533, highest value = 256
# Epoch 329/2900 : reward = 430, highest value = 128
# Epoch 330/2900 : reward = 847, highest value = 512
# Epoch 331/2900 : reward = 487, highest value = 256
# Epoch 332/2900 : reward = 468, highest value = 128
# Epoch 333/2900 : reward = 592, highest value = 256
# Epoch 334/2900 : reward = 674, highest value = 256
# Epoch 335/2900 : reward = 942, highest value = 512
# Epoch 336/2900 : reward = 714, highest value = 256
# Epoch 337/2900 : reward = 671, highest value = 256
# Epoch 338/2900 : reward = 572, highest value = 128
# Epoch 339/2900 : reward = 679, highest value = 256
# Epoch 340/2900 : reward = 939, highest value = 512
# Epoch 341/2900 : reward = 463, highest value = 128
# Epoch 342/2900 : reward = 658, highest value = 256
# Epoch 343/2900 : reward = 774, highest value = 512
# Epoch 344/2900 : reward = 623, highest value = 256
# Epoch 345/2900 : reward = 758, highest value = 256
# Epoch 346/2900 : reward = 491, highest value = 256
# Epoch 347/2900 : reward = 598, highest value = 256
# Epoch 348/2900 : reward = 602, highest value = 128
# Epoch 349/2900 : reward = 576, highest value = 256
# Epoch 350/2900 : reward = 700, highest value = 256
# Epoch 351/2900 : reward = 601, highest value = 256
# Epoch 352/2900 : reward = 482, highest value = 256
# Epoch 353/2900 : reward = 811, highest value = 512
# Epoch 354/2900 : reward = 845, highest value = 512
# Epoch 355/2900 : reward = 866, highest value = 256
# Epoch 356/2900 : reward = 489, highest value = 128
# Epoch 357/2900 : reward = 651, highest value = 256
# Epoch 358/2900 : reward = 489, highest value = 128
# Epoch 359/2900 : reward = 545, highest value = 256
# Epoch 360/2900 : reward = 786, highest value = 256
# Epoch 361/2900 : reward = 567, highest value = 256
# Epoch 362/2900 : reward = 644, highest value = 256
# Epoch 363/2900 : reward = 625, highest value = 256
# Epoch 364/2900 : reward = 590, highest value = 256
# Epoch 365/2900 : reward = 550, highest value = 256
# Epoch 366/2900 : reward = 934, highest value = 512
# Epoch 367/2900 : reward = 751, highest value = 256
# Epoch 368/2900 : reward = 374, highest value = 128
# Epoch 369/2900 : reward = 605, highest value = 256
# Epoch 370/2900 : reward = 695, highest value = 256
# Epoch 371/2900 : reward = 634, highest value = 256
# Epoch 372/2900 : reward = 442, highest value = 128
# Epoch 373/2900 : reward = 345, highest value = 128
# Epoch 374/2900 : reward = 845, highest value = 256
# Epoch 375/2900 : reward = 299, highest value = 64
# Epoch 376/2900 : reward = 335, highest value = 128
# Epoch 377/2900 : reward = 815, highest value = 512
# Epoch 378/2900 : reward = 378, highest value = 128
# Epoch 379/2900 : reward = 467, highest value = 128
# Epoch 380/2900 : reward = 775, highest value = 256
# Epoch 381/2900 : reward = 756, highest value = 256
# Epoch 382/2900 : reward = 568, highest value = 256
# Epoch 383/2900 : reward = 575, highest value = 256
# Epoch 384/2900 : reward = 889, highest value = 512
# Epoch 385/2900 : reward = 873, highest value = 512
# Epoch 386/2900 : reward = 297, highest value = 64
# Epoch 387/2900 : reward = 463, highest value = 128
# Epoch 388/2900 : reward = 1033, highest value = 512
# Epoch 389/2900 : reward = 653, highest value = 256
# Epoch 390/2900 : reward = 507, highest value = 128
# Epoch 391/2900 : reward = 589, highest value = 256
# Epoch 392/2900 : reward = 672, highest value = 256
# Epoch 393/2900 : reward = 585, highest value = 256
# Epoch 394/2900 : reward = 617, highest value = 256
# Epoch 395/2900 : reward = 663, highest value = 256
# Epoch 396/2900 : reward = 746, highest value = 256
# Epoch 397/2900 : reward = 467, highest value = 256
# Epoch 398/2900 : reward = 565, highest value = 256
# Epoch 399/2900 : reward = 983, highest value = 512
# Epoch 400/2900 : reward = 904, highest value = 512
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 7.65
# Average of high while playing : 233.6
# ----------------------------------------------------------------------
# Epoch 401/2900 : reward = 647, highest value = 256
# Epoch 402/2900 : reward = 634, highest value = 256
# Epoch 403/2900 : reward = 688, highest value = 256
# Epoch 404/2900 : reward = 751, highest value = 512
# Epoch 405/2900 : reward = 764, highest value = 256
# Epoch 406/2900 : reward = 1050, highest value = 512
# Epoch 407/2900 : reward = 660, highest value = 256
# Epoch 408/2900 : reward = 621, highest value = 256
# Epoch 409/2900 : reward = 878, highest value = 256
# Epoch 410/2900 : reward = 779, highest value = 256
# Epoch 411/2900 : reward = 399, highest value = 128
# Epoch 412/2900 : reward = 489, highest value = 128
# Epoch 413/2900 : reward = 884, highest value = 512
# Epoch 414/2900 : reward = 508, highest value = 128
# Epoch 415/2900 : reward = 587, highest value = 128
# Epoch 416/2900 : reward = 778, highest value = 512
# Epoch 417/2900 : reward = 714, highest value = 256
# Epoch 418/2900 : reward = 591, highest value = 256
# Epoch 419/2900 : reward = 981, highest value = 512
# Epoch 420/2900 : reward = 654, highest value = 256
# Epoch 421/2900 : reward = 829, highest value = 512
# Epoch 422/2900 : reward = 680, highest value = 256
# Epoch 423/2900 : reward = 705, highest value = 256
# Epoch 424/2900 : reward = 649, highest value = 256
# Epoch 425/2900 : reward = 763, highest value = 256
# Epoch 426/2900 : reward = 385, highest value = 64
# Epoch 427/2900 : reward = 930, highest value = 512
# Epoch 428/2900 : reward = 471, highest value = 128
# Epoch 429/2900 : reward = 911, highest value = 512
# Epoch 430/2900 : reward = 714, highest value = 256
# Epoch 431/2900 : reward = 836, highest value = 512
# Epoch 432/2900 : reward = 677, highest value = 256
# Epoch 433/2900 : reward = 629, highest value = 256
# Epoch 434/2900 : reward = 631, highest value = 256
# Epoch 435/2900 : reward = 683, highest value = 256
# Epoch 436/2900 : reward = 842, highest value = 256
# Epoch 437/2900 : reward = 543, highest value = 256
# Epoch 438/2900 : reward = 652, highest value = 256
# Epoch 439/2900 : reward = 388, highest value = 128
# Epoch 440/2900 : reward = 641, highest value = 256
# Epoch 441/2900 : reward = 924, highest value = 512
# Epoch 442/2900 : reward = 785, highest value = 256
# Epoch 443/2900 : reward = 448, highest value = 128
# Epoch 444/2900 : reward = 681, highest value = 256
# Epoch 445/2900 : reward = 779, highest value = 512
# Epoch 446/2900 : reward = 720, highest value = 256
# Epoch 447/2900 : reward = 1066, highest value = 512
# Epoch 448/2900 : reward = 943, highest value = 512
# Epoch 449/2900 : reward = 619, highest value = 256
# Epoch 450/2900 : reward = 690, highest value = 256
# Epoch 451/2900 : reward = 396, highest value = 128
# Epoch 452/2900 : reward = 852, highest value = 512
# Epoch 453/2900 : reward = 736, highest value = 256
# Epoch 454/2900 : reward = 467, highest value = 128
# Epoch 455/2900 : reward = 630, highest value = 256
# Epoch 456/2900 : reward = 582, highest value = 256
# Epoch 457/2900 : reward = 1008, highest value = 512
# Epoch 458/2900 : reward = 614, highest value = 256
# Epoch 459/2900 : reward = 546, highest value = 256
# Epoch 460/2900 : reward = 620, highest value = 256
# Epoch 461/2900 : reward = 564, highest value = 256
# Epoch 462/2900 : reward = 463, highest value = 128
# Epoch 463/2900 : reward = 453, highest value = 128
# Epoch 464/2900 : reward = 869, highest value = 512
# Epoch 465/2900 : reward = 660, highest value = 256
# Epoch 466/2900 : reward = 496, highest value = 128
# Epoch 467/2900 : reward = 629, highest value = 256
# Epoch 468/2900 : reward = 502, highest value = 128
# Epoch 469/2900 : reward = 935, highest value = 512
# Epoch 470/2900 : reward = 714, highest value = 256
# Epoch 471/2900 : reward = 640, highest value = 256
# Epoch 472/2900 : reward = 453, highest value = 128
# Epoch 473/2900 : reward = 902, highest value = 512
# Epoch 474/2900 : reward = 720, highest value = 256
# Epoch 475/2900 : reward = 729, highest value = 512
# Epoch 476/2900 : reward = 583, highest value = 128
# Epoch 477/2900 : reward = 645, highest value = 256
# Epoch 478/2900 : reward = 881, highest value = 512
# Epoch 479/2900 : reward = 723, highest value = 256
# Epoch 480/2900 : reward = 654, highest value = 256
# Epoch 481/2900 : reward = 703, highest value = 256
# Epoch 482/2900 : reward = 602, highest value = 256
# Epoch 483/2900 : reward = 1092, highest value = 512
# Epoch 484/2900 : reward = 706, highest value = 256
# Epoch 485/2900 : reward = 679, highest value = 256
# Epoch 486/2900 : reward = 521, highest value = 256
# Epoch 487/2900 : reward = 335, highest value = 64
# Epoch 488/2900 : reward = 676, highest value = 256
# Epoch 489/2900 : reward = 957, highest value = 512
# Epoch 490/2900 : reward = 534, highest value = 256
# Epoch 491/2900 : reward = 604, highest value = 256
# Epoch 492/2900 : reward = 794, highest value = 512
# Epoch 493/2900 : reward = 822, highest value = 256
# Epoch 494/2900 : reward = 783, highest value = 512
# Epoch 495/2900 : reward = 613, highest value = 256
# Epoch 496/2900 : reward = 690, highest value = 256
# Epoch 497/2900 : reward = 674, highest value = 256
# Epoch 498/2900 : reward = 768, highest value = 256
# Epoch 499/2900 : reward = 499, highest value = 128
# Epoch 500/2900 : reward = 596, highest value = 256
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 8.0
# Average of high while playing : 291.2
# ----------------------------------------------------------------------
# Epoch 501/2900 : reward = 631, highest value = 256
# Epoch 502/2900 : reward = 604, highest value = 256
# Epoch 503/2900 : reward = 416, highest value = 128
# Epoch 504/2900 : reward = 979, highest value = 512
# Epoch 505/2900 : reward = 661, highest value = 512
# Epoch 506/2900 : reward = 487, highest value = 128
# Epoch 507/2900 : reward = 928, highest value = 512
# Epoch 508/2900 : reward = 843, highest value = 512
# Epoch 509/2900 : reward = 644, highest value = 256
# Epoch 510/2900 : reward = 551, highest value = 256
# Epoch 511/2900 : reward = 665, highest value = 256
# Epoch 512/2900 : reward = 531, highest value = 128
# Epoch 513/2900 : reward = 974, highest value = 512
# Epoch 514/2900 : reward = 532, highest value = 128
# Epoch 515/2900 : reward = 656, highest value = 256
# Epoch 516/2900 : reward = 594, highest value = 256
# Epoch 517/2900 : reward = 467, highest value = 128
# Epoch 518/2900 : reward = 519, highest value = 128
# Epoch 519/2900 : reward = 353, highest value = 128
# Epoch 520/2900 : reward = 881, highest value = 512
# Epoch 521/2900 : reward = 481, highest value = 128
# Epoch 522/2900 : reward = 570, highest value = 128
# Epoch 523/2900 : reward = 370, highest value = 64
# Epoch 524/2900 : reward = 937, highest value = 512
# Epoch 525/2900 : reward = 703, highest value = 256
# Epoch 526/2900 : reward = 689, highest value = 256
# Epoch 527/2900 : reward = 636, highest value = 256
# Epoch 528/2900 : reward = 755, highest value = 256
# Epoch 529/2900 : reward = 605, highest value = 256
# Epoch 530/2900 : reward = 692, highest value = 256
# Epoch 531/2900 : reward = 581, highest value = 256
# Epoch 532/2900 : reward = 645, highest value = 256
# Epoch 533/2900 : reward = 453, highest value = 128
# Epoch 534/2900 : reward = 651, highest value = 256
# Epoch 535/2900 : reward = 685, highest value = 256
# Epoch 536/2900 : reward = 809, highest value = 512
# Epoch 537/2900 : reward = 651, highest value = 256
# Epoch 538/2900 : reward = 581, highest value = 256
# Epoch 539/2900 : reward = 657, highest value = 256
# Epoch 540/2900 : reward = 832, highest value = 512
# Epoch 541/2900 : reward = 720, highest value = 256
# Epoch 542/2900 : reward = 638, highest value = 256
# Epoch 543/2900 : reward = 988, highest value = 512
# Epoch 544/2900 : reward = 860, highest value = 256
# Epoch 545/2900 : reward = 951, highest value = 512
# Epoch 546/2900 : reward = 847, highest value = 256
# Epoch 547/2900 : reward = 469, highest value = 128
# Epoch 548/2900 : reward = 572, highest value = 256
# Epoch 549/2900 : reward = 690, highest value = 256
# Epoch 550/2900 : reward = 621, highest value = 256
# Epoch 551/2900 : reward = 686, highest value = 256
# Epoch 552/2900 : reward = 429, highest value = 128
# Epoch 553/2900 : reward = 635, highest value = 256
# Epoch 554/2900 : reward = 633, highest value = 256
# Epoch 555/2900 : reward = 411, highest value = 128
# Epoch 556/2900 : reward = 590, highest value = 256
# Epoch 557/2900 : reward = 1089, highest value = 512
# Epoch 558/2900 : reward = 584, highest value = 256
# Epoch 559/2900 : reward = 910, highest value = 512
# Epoch 560/2900 : reward = 631, highest value = 256
# Epoch 561/2900 : reward = 548, highest value = 128
# Epoch 562/2900 : reward = 785, highest value = 256
# Epoch 563/2900 : reward = 264, highest value = 64
# Epoch 564/2900 : reward = 720, highest value = 256
# Epoch 565/2900 : reward = 960, highest value = 512
# Epoch 566/2900 : reward = 743, highest value = 256
# Epoch 567/2900 : reward = 484, highest value = 128
# Epoch 568/2900 : reward = 467, highest value = 128
# Epoch 569/2900 : reward = 707, highest value = 256
# Epoch 570/2900 : reward = 648, highest value = 256
# Epoch 571/2900 : reward = 354, highest value = 64
# Epoch 572/2900 : reward = 794, highest value = 256
# Epoch 573/2900 : reward = 734, highest value = 256
# Epoch 574/2900 : reward = 905, highest value = 512
# Epoch 575/2900 : reward = 796, highest value = 512
# Epoch 576/2900 : reward = 581, highest value = 256
# Epoch 577/2900 : reward = 729, highest value = 256
# Epoch 578/2900 : reward = 372, highest value = 128
# Epoch 579/2900 : reward = 794, highest value = 512
# Epoch 580/2900 : reward = 579, highest value = 256
# Epoch 581/2900 : reward = 838, highest value = 256
# Epoch 582/2900 : reward = 489, highest value = 128
# Epoch 583/2900 : reward = 611, highest value = 256
# Epoch 584/2900 : reward = 572, highest value = 256
# Epoch 585/2900 : reward = 658, highest value = 256
# Epoch 586/2900 : reward = 527, highest value = 128
# Epoch 587/2900 : reward = 864, highest value = 512
# Epoch 588/2900 : reward = 624, highest value = 256
# Epoch 589/2900 : reward = 854, highest value = 512
# Epoch 590/2900 : reward = 880, highest value = 512
# Epoch 591/2900 : reward = 979, highest value = 512
# Epoch 592/2900 : reward = 923, highest value = 512
# Epoch 593/2900 : reward = 552, highest value = 128
# Epoch 594/2900 : reward = 1016, highest value = 512
# Epoch 595/2900 : reward = 366, highest value = 64
# Epoch 596/2900 : reward = 583, highest value = 256
# Epoch 597/2900 : reward = 560, highest value = 256
# Epoch 598/2900 : reward = 1096, highest value = 512
# Epoch 599/2900 : reward = 1098, highest value = 512
# Epoch 600/2900 : reward = 315, highest value = 64
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 8.0
# Average of high while playing : 297.6
# ----------------------------------------------------------------------
# Epoch 601/2900 : reward = 709, highest value = 256
# Epoch 602/2900 : reward = 1046, highest value = 512
# Epoch 603/2900 : reward = 955, highest value = 512
# Epoch 604/2900 : reward = 988, highest value = 512
# Epoch 605/2900 : reward = 323, highest value = 128
# Epoch 606/2900 : reward = 491, highest value = 128
# Epoch 607/2900 : reward = 968, highest value = 512
# Epoch 608/2900 : reward = 523, highest value = 128
# Epoch 609/2900 : reward = 480, highest value = 128
# Epoch 610/2900 : reward = 990, highest value = 512
# Epoch 611/2900 : reward = 487, highest value = 128
# Epoch 612/2900 : reward = 719, highest value = 512
# Epoch 613/2900 : reward = 744, highest value = 256
# Epoch 614/2900 : reward = 370, highest value = 128
# Epoch 615/2900 : reward = 1128, highest value = 512
# Epoch 616/2900 : reward = 475, highest value = 256
# Epoch 617/2900 : reward = 679, highest value = 256
# Epoch 618/2900 : reward = 704, highest value = 256
# Epoch 619/2900 : reward = 666, highest value = 256
# Epoch 620/2900 : reward = 673, highest value = 256
# Epoch 621/2900 : reward = 566, highest value = 256
# Epoch 622/2900 : reward = 450, highest value = 128
# Epoch 623/2900 : reward = 554, highest value = 256
# Epoch 624/2900 : reward = 532, highest value = 128
# Epoch 625/2900 : reward = 991, highest value = 512
# Epoch 626/2900 : reward = 508, highest value = 128
# Epoch 627/2900 : reward = 1094, highest value = 512
# Epoch 628/2900 : reward = 359, highest value = 64
# Epoch 629/2900 : reward = 777, highest value = 256
# Epoch 630/2900 : reward = 416, highest value = 128
# Epoch 631/2900 : reward = 661, highest value = 256
# Epoch 632/2900 : reward = 686, highest value = 256
# Epoch 633/2900 : reward = 666, highest value = 256
# Epoch 634/2900 : reward = 717, highest value = 256
# Epoch 635/2900 : reward = 771, highest value = 256
# Epoch 636/2900 : reward = 626, highest value = 256
# Epoch 637/2900 : reward = 442, highest value = 128
# Epoch 638/2900 : reward = 660, highest value = 256
# Epoch 639/2900 : reward = 612, highest value = 256
# Epoch 640/2900 : reward = 805, highest value = 256
# Epoch 641/2900 : reward = 694, highest value = 256
# Epoch 642/2900 : reward = 831, highest value = 512
# Epoch 643/2900 : reward = 820, highest value = 256
# Epoch 644/2900 : reward = 714, highest value = 256
# Epoch 645/2900 : reward = 755, highest value = 256
# Epoch 646/2900 : reward = 603, highest value = 256
# Epoch 647/2900 : reward = 863, highest value = 256
# Epoch 648/2900 : reward = 443, highest value = 128
# Epoch 649/2900 : reward = 791, highest value = 256
# Epoch 650/2900 : reward = 490, highest value = 128
# Epoch 651/2900 : reward = 686, highest value = 256
# Epoch 652/2900 : reward = 632, highest value = 256
# Epoch 653/2900 : reward = 503, highest value = 256
# Epoch 654/2900 : reward = 448, highest value = 128
# Epoch 655/2900 : reward = 677, highest value = 256
# Epoch 656/2900 : reward = 1057, highest value = 512
# Epoch 657/2900 : reward = 849, highest value = 512
# Epoch 658/2900 : reward = 966, highest value = 512
# Epoch 659/2900 : reward = 729, highest value = 256
# Epoch 660/2900 : reward = 627, highest value = 256
# Epoch 661/2900 : reward = 672, highest value = 256
# Epoch 662/2900 : reward = 398, highest value = 128
# Epoch 663/2900 : reward = 562, highest value = 256
# Epoch 664/2900 : reward = 672, highest value = 256
# Epoch 665/2900 : reward = 701, highest value = 256
# Epoch 666/2900 : reward = 437, highest value = 128
# Epoch 667/2900 : reward = 809, highest value = 512
# Epoch 668/2900 : reward = 951, highest value = 512
# Epoch 669/2900 : reward = 458, highest value = 128
# Epoch 670/2900 : reward = 637, highest value = 256
# Epoch 671/2900 : reward = 1067, highest value = 512
# Epoch 672/2900 : reward = 654, highest value = 256
# Epoch 673/2900 : reward = 489, highest value = 128
# Epoch 674/2900 : reward = 1119, highest value = 512
# Epoch 675/2900 : reward = 787, highest value = 256
# Epoch 676/2900 : reward = 582, highest value = 128
# Epoch 677/2900 : reward = 559, highest value = 128
# Epoch 678/2900 : reward = 576, highest value = 128
# Epoch 679/2900 : reward = 496, highest value = 128
# Epoch 680/2900 : reward = 394, highest value = 128
# Epoch 681/2900 : reward = 720, highest value = 256
# Epoch 682/2900 : reward = 908, highest value = 512
# Epoch 683/2900 : reward = 630, highest value = 256
# Epoch 684/2900 : reward = 615, highest value = 256
# Epoch 685/2900 : reward = 618, highest value = 256
# Epoch 686/2900 : reward = 649, highest value = 256
# Epoch 687/2900 : reward = 955, highest value = 512
# Epoch 688/2900 : reward = 707, highest value = 256
# Epoch 689/2900 : reward = 394, highest value = 128
# Epoch 690/2900 : reward = 964, highest value = 512
# Epoch 691/2900 : reward = 822, highest value = 256
# Epoch 692/2900 : reward = 1157, highest value = 512
# Epoch 693/2900 : reward = 523, highest value = 256
# Epoch 694/2900 : reward = 1056, highest value = 512
# Epoch 695/2900 : reward = 898, highest value = 512
# Epoch 696/2900 : reward = 850, highest value = 512
# Epoch 697/2900 : reward = 1367, highest value = 512
# Epoch 698/2900 : reward = 774, highest value = 256
# Epoch 699/2900 : reward = 865, highest value = 512
# Epoch 700/2900 : reward = 936, highest value = 512
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 8.25
# Average of high while playing : 348.8
# ----------------------------------------------------------------------
# Epoch 701/2900 : reward = 605, highest value = 256
# Epoch 702/2900 : reward = 808, highest value = 256
# Epoch 703/2900 : reward = 1175, highest value = 512
# Epoch 704/2900 : reward = 898, highest value = 512
# Epoch 705/2900 : reward = 553, highest value = 128
# Epoch 706/2900 : reward = 862, highest value = 512
# Epoch 707/2900 : reward = 1007, highest value = 512
# Epoch 708/2900 : reward = 651, highest value = 256
# Epoch 709/2900 : reward = 446, highest value = 128
# Epoch 710/2900 : reward = 739, highest value = 512
# Epoch 711/2900 : reward = 863, highest value = 512
# Epoch 712/2900 : reward = 829, highest value = 512
# Epoch 713/2900 : reward = 974, highest value = 512
# Epoch 714/2900 : reward = 604, highest value = 128
# Epoch 715/2900 : reward = 755, highest value = 256
# Epoch 716/2900 : reward = 780, highest value = 256
# Epoch 717/2900 : reward = 732, highest value = 256
# Epoch 718/2900 : reward = 604, highest value = 256
# Epoch 719/2900 : reward = 421, highest value = 128
# Epoch 720/2900 : reward = 547, highest value = 128
# Epoch 721/2900 : reward = 700, highest value = 256
# Epoch 722/2900 : reward = 495, highest value = 128
# Epoch 723/2900 : reward = 970, highest value = 512
# Epoch 724/2900 : reward = 934, highest value = 512
# Epoch 725/2900 : reward = 563, highest value = 256
# Epoch 726/2900 : reward = 912, highest value = 512
# Epoch 727/2900 : reward = 998, highest value = 512
# Epoch 728/2900 : reward = 587, highest value = 256
# Epoch 729/2900 : reward = 492, highest value = 128
# Epoch 730/2900 : reward = 761, highest value = 256
# Epoch 731/2900 : reward = 1146, highest value = 512
# Epoch 732/2900 : reward = 657, highest value = 256
# Epoch 733/2900 : reward = 392, highest value = 128
# Epoch 734/2900 : reward = 928, highest value = 512
# Epoch 735/2900 : reward = 1020, highest value = 512
# Epoch 736/2900 : reward = 684, highest value = 256
# Epoch 737/2900 : reward = 1034, highest value = 512
# Epoch 738/2900 : reward = 579, highest value = 256
# Epoch 739/2900 : reward = 927, highest value = 512
# Epoch 740/2900 : reward = 473, highest value = 128
# Epoch 741/2900 : reward = 1020, highest value = 512
# Epoch 742/2900 : reward = 1033, highest value = 512
# Epoch 743/2900 : reward = 714, highest value = 256
# Epoch 744/2900 : reward = 953, highest value = 512
# Epoch 745/2900 : reward = 1563, highest value = 1024
# Epoch 746/2900 : reward = 727, highest value = 256
# Epoch 747/2900 : reward = 926, highest value = 512
# Epoch 748/2900 : reward = 1193, highest value = 512
# Epoch 749/2900 : reward = 1120, highest value = 512
# Epoch 750/2900 : reward = 909, highest value = 512
# Epoch 751/2900 : reward = 722, highest value = 256
# Epoch 752/2900 : reward = 971, highest value = 256
# Epoch 753/2900 : reward = 615, highest value = 256
# Epoch 754/2900 : reward = 1192, highest value = 1024
# Epoch 755/2900 : reward = 842, highest value = 256
# Epoch 756/2900 : reward = 823, highest value = 256
# Epoch 757/2900 : reward = 768, highest value = 256
# Epoch 758/2900 : reward = 873, highest value = 512
# Epoch 759/2900 : reward = 858, highest value = 256
# Epoch 760/2900 : reward = 1003, highest value = 512
# Epoch 761/2900 : reward = 435, highest value = 128
# Epoch 762/2900 : reward = 748, highest value = 256
# Epoch 763/2900 : reward = 1289, highest value = 512
# Epoch 764/2900 : reward = 1083, highest value = 512
# Epoch 765/2900 : reward = 1130, highest value = 512
# Epoch 766/2900 : reward = 757, highest value = 256
# Epoch 767/2900 : reward = 317, highest value = 64
# Epoch 768/2900 : reward = 362, highest value = 128
# Epoch 769/2900 : reward = 641, highest value = 256
# Epoch 770/2900 : reward = 938, highest value = 512
# Epoch 771/2900 : reward = 642, highest value = 256
# Epoch 772/2900 : reward = 735, highest value = 256
# Epoch 773/2900 : reward = 450, highest value = 128
# Epoch 774/2900 : reward = 955, highest value = 512
# Epoch 775/2900 : reward = 795, highest value = 256
# Epoch 776/2900 : reward = 949, highest value = 512
# Epoch 777/2900 : reward = 731, highest value = 256
# Epoch 778/2900 : reward = 922, highest value = 512
# Epoch 779/2900 : reward = 726, highest value = 512
# Epoch 780/2900 : reward = 929, highest value = 512
# Epoch 781/2900 : reward = 446, highest value = 128
# Epoch 782/2900 : reward = 598, highest value = 256
# Epoch 783/2900 : reward = 660, highest value = 256
# Epoch 784/2900 : reward = 609, highest value = 256
# Epoch 785/2900 : reward = 692, highest value = 256
# Epoch 786/2900 : reward = 482, highest value = 128
# Epoch 787/2900 : reward = 717, highest value = 256
# Epoch 788/2900 : reward = 1002, highest value = 512
# Epoch 789/2900 : reward = 973, highest value = 512
# Epoch 790/2900 : reward = 797, highest value = 256
# Epoch 791/2900 : reward = 1245, highest value = 512
# Epoch 792/2900 : reward = 1212, highest value = 512
# Epoch 793/2900 : reward = 715, highest value = 256
# Epoch 794/2900 : reward = 897, highest value = 512
# Epoch 795/2900 : reward = 698, highest value = 256
# Epoch 796/2900 : reward = 1223, highest value = 512
# Epoch 797/2900 : reward = 467, highest value = 128
# Epoch 798/2900 : reward = 601, highest value = 256
# Epoch 799/2900 : reward = 614, highest value = 256
# Epoch 800/2900 : reward = 1405, highest value = 1024
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 8.4
# Average of high while playing : 384.0
# ----------------------------------------------------------------------
# Epoch 801/2900 : reward = 857, highest value = 256
# Epoch 802/2900 : reward = 735, highest value = 256
# Epoch 803/2900 : reward = 821, highest value = 512
# Epoch 804/2900 : reward = 659, highest value = 256
# Epoch 805/2900 : reward = 654, highest value = 256
# Epoch 806/2900 : reward = 1166, highest value = 512
# Epoch 807/2900 : reward = 833, highest value = 512
# Epoch 808/2900 : reward = 1086, highest value = 512
# Epoch 809/2900 : reward = 985, highest value = 256
# Epoch 810/2900 : reward = 680, highest value = 256
# Epoch 811/2900 : reward = 694, highest value = 256
# Epoch 812/2900 : reward = 1114, highest value = 512
# Epoch 813/2900 : reward = 981, highest value = 256
# Epoch 814/2900 : reward = 927, highest value = 256
# Epoch 815/2900 : reward = 1257, highest value = 512
# Epoch 816/2900 : reward = 1010, highest value = 512
# Epoch 817/2900 : reward = 944, highest value = 512
# Epoch 818/2900 : reward = 352, highest value = 128
# Epoch 819/2900 : reward = 988, highest value = 512
# Epoch 820/2900 : reward = 949, highest value = 512
# Epoch 821/2900 : reward = 707, highest value = 256
# Epoch 822/2900 : reward = 764, highest value = 256
# Epoch 823/2900 : reward = 878, highest value = 512
# Epoch 824/2900 : reward = 750, highest value = 256
# Epoch 825/2900 : reward = 694, highest value = 256
# Epoch 826/2900 : reward = 1071, highest value = 512
# Epoch 827/2900 : reward = 656, highest value = 256
# Epoch 828/2900 : reward = 1434, highest value = 512
# Epoch 829/2900 : reward = 1167, highest value = 512
# Epoch 830/2900 : reward = 731, highest value = 256
# Epoch 831/2900 : reward = 1202, highest value = 512
# Epoch 832/2900 : reward = 908, highest value = 512
# Epoch 833/2900 : reward = 1220, highest value = 512
# Epoch 834/2900 : reward = 690, highest value = 256
# Epoch 835/2900 : reward = 1033, highest value = 512
# Epoch 836/2900 : reward = 636, highest value = 256
# Epoch 837/2900 : reward = 1157, highest value = 512
# Epoch 838/2900 : reward = 1341, highest value = 512
# Epoch 839/2900 : reward = 848, highest value = 256
# Epoch 840/2900 : reward = 953, highest value = 512
# Epoch 841/2900 : reward = 1154, highest value = 512
# Epoch 842/2900 : reward = 702, highest value = 256
# Epoch 843/2900 : reward = 409, highest value = 128
# Epoch 844/2900 : reward = 1152, highest value = 512
# Epoch 845/2900 : reward = 680, highest value = 256
# Epoch 846/2900 : reward = 1313, highest value = 512
# Epoch 847/2900 : reward = 1167, highest value = 512
# Epoch 848/2900 : reward = 1098, highest value = 512
# Epoch 849/2900 : reward = 699, highest value = 256
# Epoch 850/2900 : reward = 766, highest value = 256
# Epoch 851/2900 : reward = 644, highest value = 256
# Epoch 852/2900 : reward = 1068, highest value = 512
# Epoch 853/2900 : reward = 393, highest value = 128
# Epoch 854/2900 : reward = 1221, highest value = 512
# Epoch 855/2900 : reward = 682, highest value = 256
# Epoch 856/2900 : reward = 1174, highest value = 512
# Epoch 857/2900 : reward = 1128, highest value = 512
# Epoch 858/2900 : reward = 666, highest value = 256
# Epoch 859/2900 : reward = 462, highest value = 128
# Epoch 860/2900 : reward = 432, highest value = 128
# Epoch 861/2900 : reward = 1422, highest value = 512
# Epoch 862/2900 : reward = 1049, highest value = 512
# Epoch 863/2900 : reward = 389, highest value = 128
# Epoch 864/2900 : reward = 1783, highest value = 1024
# Epoch 865/2900 : reward = 960, highest value = 512
# Epoch 866/2900 : reward = 1190, highest value = 512
# Epoch 867/2900 : reward = 1301, highest value = 512
# Epoch 868/2900 : reward = 891, highest value = 256
# Epoch 869/2900 : reward = 834, highest value = 256
# Epoch 870/2900 : reward = 464, highest value = 128
# Epoch 871/2900 : reward = 757, highest value = 256
# Epoch 872/2900 : reward = 894, highest value = 512
# Epoch 873/2900 : reward = 568, highest value = 256
# Epoch 874/2900 : reward = 742, highest value = 256
# Epoch 875/2900 : reward = 737, highest value = 512
# Epoch 876/2900 : reward = 1014, highest value = 512
# Epoch 877/2900 : reward = 588, highest value = 256
# Epoch 878/2900 : reward = 680, highest value = 256
# Epoch 879/2900 : reward = 1182, highest value = 512
# Epoch 880/2900 : reward = 1510, highest value = 1024
# Epoch 881/2900 : reward = 714, highest value = 256
# Epoch 882/2900 : reward = 1389, highest value = 1024
# Epoch 883/2900 : reward = 687, highest value = 256
# Epoch 884/2900 : reward = 487, highest value = 128
# Epoch 885/2900 : reward = 648, highest value = 256
# Epoch 886/2900 : reward = 1244, highest value = 512
# Epoch 887/2900 : reward = 1372, highest value = 1024
# Epoch 888/2900 : reward = 1275, highest value = 512
# Epoch 889/2900 : reward = 932, highest value = 512
# Epoch 890/2900 : reward = 364, highest value = 64
# Epoch 891/2900 : reward = 727, highest value = 256
# Epoch 892/2900 : reward = 1181, highest value = 512
# Epoch 893/2900 : reward = 806, highest value = 256
# Epoch 894/2900 : reward = 1162, highest value = 512
# Epoch 895/2900 : reward = 493, highest value = 128
# Epoch 896/2900 : reward = 628, highest value = 256
# Epoch 897/2900 : reward = 697, highest value = 256
# Epoch 898/2900 : reward = 440, highest value = 128
# Epoch 899/2900 : reward = 1309, highest value = 512
# Epoch 900/2900 : reward = 1028, highest value = 512
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 8.5
# Average of high while playing : 403.2
# ----------------------------------------------------------------------
# ...
# Epoch 2615/2900 : reward = 509, highest value = 128
# Epoch 2616/2900 : reward = 970, highest value = 512
# Epoch 2617/2900 : reward = 1018, highest value = 512
# Epoch 2618/2900 : reward = 385, highest value = 128
# Epoch 2619/2900 : reward = 1346, highest value = 512
# Epoch 2620/2900 : reward = 746, highest value = 256
# Epoch 2621/2900 : reward = 584, highest value = 256
# Epoch 2622/2900 : reward = 1604, highest value = 1024
# Epoch 2623/2900 : reward = 1247, highest value = 512
# Epoch 2624/2900 : reward = 1137, highest value = 512
# Epoch 2625/2900 : reward = 938, highest value = 512
# Epoch 2626/2900 : reward = 1182, highest value = 512
# Epoch 2627/2900 : reward = 858, highest value = 256
# Epoch 2628/2900 : reward = 444, highest value = 128
# Epoch 2629/2900 : reward = 1486, highest value = 1024
# Epoch 2630/2900 : reward = 775, highest value = 256
# Epoch 2631/2900 : reward = 1145, highest value = 512
# Epoch 2632/2900 : reward = 845, highest value = 256
# Epoch 2633/2900 : reward = 1209, highest value = 512
# Epoch 2634/2900 : reward = 716, highest value = 256
# Epoch 2635/2900 : reward = 683, highest value = 256
# Epoch 2636/2900 : reward = 773, highest value = 512
# Epoch 2637/2900 : reward = 1363, highest value = 512
# Epoch 2638/2900 : reward = 1322, highest value = 512
# Epoch 2639/2900 : reward = 383, highest value = 128
# Epoch 2640/2900 : reward = 1401, highest value = 512
# Epoch 2641/2900 : reward = 718, highest value = 256
# Epoch 2642/2900 : reward = 1874, highest value = 1024
# Epoch 2643/2900 : reward = 663, highest value = 256
# Epoch 2644/2900 : reward = 333, highest value = 64
# Epoch 2645/2900 : reward = 1555, highest value = 1024
# Epoch 2646/2900 : reward = 428, highest value = 128
# Epoch 2647/2900 : reward = 2357, highest value = 1024
# Epoch 2648/2900 : reward = 999, highest value = 512
# Epoch 2649/2900 : reward = 1176, highest value = 512
# Epoch 2650/2900 : reward = 1369, highest value = 512
# Epoch 2651/2900 : reward = 997, highest value = 512
# Epoch 2652/2900 : reward = 757, highest value = 256
# Epoch 2653/2900 : reward = 864, highest value = 256
# Epoch 2654/2900 : reward = 1217, highest value = 512
# Epoch 2655/2900 : reward = 941, highest value = 256
# Epoch 2656/2900 : reward = 384, highest value = 128
# Epoch 2657/2900 : reward = 678, highest value = 256
# Epoch 2658/2900 : reward = 943, highest value = 512
# Epoch 2659/2900 : reward = 406, highest value = 128
# Epoch 2660/2900 : reward = 1194, highest value = 512
# Epoch 2661/2900 : reward = 1272, highest value = 512
# Epoch 2662/2900 : reward = 411, highest value = 128
# Epoch 2663/2900 : reward = 885, highest value = 512
# Epoch 2664/2900 : reward = 1057, highest value = 512
# Epoch 2665/2900 : reward = 738, highest value = 256
# Epoch 2666/2900 : reward = 1331, highest value = 512
# Epoch 2667/2900 : reward = 604, highest value = 256
# Epoch 2668/2900 : reward = 1236, highest value = 512
# Epoch 2669/2900 : reward = 287, highest value = 64
# Epoch 2670/2900 : reward = 322, highest value = 64
# Epoch 2671/2900 : reward = 1141, highest value = 512
# Epoch 2672/2900 : reward = 1013, highest value = 256
# Epoch 2673/2900 : reward = 1025, highest value = 512
# Epoch 2674/2900 : reward = 959, highest value = 256
# Epoch 2675/2900 : reward = 2316, highest value = 1024
# Epoch 2676/2900 : reward = 509, highest value = 128
# Epoch 2677/2900 : reward = 499, highest value = 128
# Epoch 2678/2900 : reward = 664, highest value = 256
# Epoch 2679/2900 : reward = 1473, highest value = 512
# Epoch 2680/2900 : reward = 275, highest value = 64
# Epoch 2681/2900 : reward = 499, highest value = 128
# Epoch 2682/2900 : reward = 893, highest value = 512
# Epoch 2683/2900 : reward = 770, highest value = 256
# Epoch 2684/2900 : reward = 1128, highest value = 512
# Epoch 2685/2900 : reward = 1068, highest value = 512
# Epoch 2686/2900 : reward = 414, highest value = 128
# Epoch 2687/2900 : reward = 1668, highest value = 512
# Epoch 2688/2900 : reward = 1949, highest value = 1024
# Epoch 2689/2900 : reward = 1352, highest value = 512
# Epoch 2690/2900 : reward = 583, highest value = 128
# Epoch 2691/2900 : reward = 305, highest value = 64
# Epoch 2692/2900 : reward = 970, highest value = 512
# Epoch 2693/2900 : reward = 762, highest value = 256
# Epoch 2694/2900 : reward = 772, highest value = 256
# Epoch 2695/2900 : reward = 860, highest value = 256
# Epoch 2696/2900 : reward = 898, highest value = 512
# Epoch 2697/2900 : reward = 327, highest value = 64
# Epoch 2698/2900 : reward = 633, highest value = 256
# Epoch 2699/2900 : reward = 507, highest value = 256
# Epoch 2700/2900 : reward = 1036, highest value = 512
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 8.3
# Average of high while playing : 345.6
# ----------------------------------------------------------------------
# Epoch 2701/2900 : reward = 890, highest value = 512
# Epoch 2702/2900 : reward = 861, highest value = 512
# Epoch 2703/2900 : reward = 604, highest value = 256
# Epoch 2704/2900 : reward = 1126, highest value = 512
# Epoch 2705/2900 : reward = 677, highest value = 256
# Epoch 2706/2900 : reward = 1299, highest value = 512
# Epoch 2707/2900 : reward = 561, highest value = 256
# Epoch 2708/2900 : reward = 1153, highest value = 512
# Epoch 2709/2900 : reward = 881, highest value = 512
# Epoch 2710/2900 : reward = 938, highest value = 512
# Epoch 2711/2900 : reward = 927, highest value = 512
# Epoch 2712/2900 : reward = 914, highest value = 256
# Epoch 2713/2900 : reward = 1824, highest value = 1024
# Epoch 2714/2900 : reward = 826, highest value = 256
# Epoch 2715/2900 : reward = 1116, highest value = 512
# Epoch 2716/2900 : reward = 625, highest value = 256
# Epoch 2717/2900 : reward = 631, highest value = 256
# Epoch 2718/2900 : reward = 769, highest value = 256
# Epoch 2719/2900 : reward = 1728, highest value = 1024
# Epoch 2720/2900 : reward = 438, highest value = 128
# Epoch 2721/2900 : reward = 606, highest value = 256
# Epoch 2722/2900 : reward = 1964, highest value = 1024
# Epoch 2723/2900 : reward = 619, highest value = 256
# Epoch 2724/2900 : reward = 1044, highest value = 512
# Epoch 2725/2900 : reward = 783, highest value = 256
# Epoch 2726/2900 : reward = 1035, highest value = 256
# Epoch 2727/2900 : reward = 1073, highest value = 512
# Epoch 2728/2900 : reward = 672, highest value = 256
# Epoch 2729/2900 : reward = 1246, highest value = 512
# Epoch 2730/2900 : reward = 1262, highest value = 512
# Epoch 2731/2900 : reward = 2290, highest value = 1024
# Epoch 2732/2900 : reward = 2072, highest value = 1024
# Epoch 2733/2900 : reward = 953, highest value = 512
# Epoch 2734/2900 : reward = 859, highest value = 256
# Epoch 2735/2900 : reward = 858, highest value = 256
# Epoch 2736/2900 : reward = 899, highest value = 256
# Epoch 2737/2900 : reward = 714, highest value = 256
# Epoch 2738/2900 : reward = 702, highest value = 256
# Epoch 2739/2900 : reward = 564, highest value = 256
# Epoch 2740/2900 : reward = 988, highest value = 512
# Epoch 2741/2900 : reward = 743, highest value = 256
# Epoch 2742/2900 : reward = 1480, highest value = 512
# Epoch 2743/2900 : reward = 307, highest value = 64
# Epoch 2744/2900 : reward = 1797, highest value = 1024
# Epoch 2745/2900 : reward = 711, highest value = 256
# Epoch 2746/2900 : reward = 819, highest value = 256
# Epoch 2747/2900 : reward = 1566, highest value = 1024
# Epoch 2748/2900 : reward = 936, highest value = 512
# Epoch 2749/2900 : reward = 1015, highest value = 512
# Epoch 2750/2900 : reward = 1261, highest value = 512
# Epoch 2751/2900 : reward = 733, highest value = 256
# Epoch 2752/2900 : reward = 1244, highest value = 512
# Epoch 2753/2900 : reward = 548, highest value = 128
# Epoch 2754/2900 : reward = 1314, highest value = 512
# Epoch 2755/2900 : reward = 1603, highest value = 1024
# Epoch 2756/2900 : reward = 1183, highest value = 512
# Epoch 2757/2900 : reward = 451, highest value = 128
# Epoch 2758/2900 : reward = 644, highest value = 256
# Epoch 2759/2900 : reward = 556, highest value = 256
# Epoch 2760/2900 : reward = 673, highest value = 256
# Epoch 2761/2900 : reward = 979, highest value = 256
# Epoch 2762/2900 : reward = 648, highest value = 256
# Epoch 2763/2900 : reward = 1125, highest value = 512
# Epoch 2764/2900 : reward = 1330, highest value = 512
# Epoch 2765/2900 : reward = 839, highest value = 256
# Epoch 2766/2900 : reward = 487, highest value = 128
# Epoch 2767/2900 : reward = 674, highest value = 256
# Epoch 2768/2900 : reward = 1147, highest value = 256
# Epoch 2769/2900 : reward = 1865, highest value = 1024
# Epoch 2770/2900 : reward = 1874, highest value = 1024
# Epoch 2771/2900 : reward = 866, highest value = 256
# Epoch 2772/2900 : reward = 437, highest value = 128
# Epoch 2773/2900 : reward = 438, highest value = 128
# Epoch 2774/2900 : reward = 853, highest value = 512
# Epoch 2775/2900 : reward = 829, highest value = 256
# Epoch 2776/2900 : reward = 434, highest value = 128
# Epoch 2777/2900 : reward = 1394, highest value = 1024
# Epoch 2778/2900 : reward = 563, highest value = 256
# Epoch 2779/2900 : reward = 1000, highest value = 512
# Epoch 2780/2900 : reward = 843, highest value = 512
# Epoch 2781/2900 : reward = 421, highest value = 128
# Epoch 2782/2900 : reward = 919, highest value = 512
# Epoch 2783/2900 : reward = 801, highest value = 256
# Epoch 2784/2900 : reward = 739, highest value = 256
# Epoch 2785/2900 : reward = 711, highest value = 256
# Epoch 2786/2900 : reward = 500, highest value = 128
# Epoch 2787/2900 : reward = 1151, highest value = 512
# Epoch 2788/2900 : reward = 500, highest value = 256
# Epoch 2789/2900 : reward = 710, highest value = 256
# Epoch 2790/2900 : reward = 477, highest value = 256
# Epoch 2791/2900 : reward = 428, highest value = 128
# Epoch 2792/2900 : reward = 595, highest value = 256
# Epoch 2793/2900 : reward = 1071, highest value = 512
# Epoch 2794/2900 : reward = 544, highest value = 128
# Epoch 2795/2900 : reward = 585, highest value = 256
# Epoch 2796/2900 : reward = 571, highest value = 256
# Epoch 2797/2900 : reward = 1558, highest value = 1024
# Epoch 2798/2900 : reward = 456, highest value = 128
# Epoch 2799/2900 : reward = 1028, highest value = 512
# Epoch 2800/2900 : reward = 640, highest value = 256
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 8.6
# Average of high while playing : 441.6
# ----------------------------------------------------------------------
# Epoch 2801/2900 : reward = 805, highest value = 256
# Epoch 2802/2900 : reward = 383, highest value = 64
# Epoch 2803/2900 : reward = 1072, highest value = 512
# Epoch 2804/2900 : reward = 878, highest value = 512
# Epoch 2805/2900 : reward = 596, highest value = 256
# Epoch 2806/2900 : reward = 886, highest value = 512
# Epoch 2807/2900 : reward = 676, highest value = 256
# Epoch 2808/2900 : reward = 1115, highest value = 512
# Epoch 2809/2900 : reward = 1594, highest value = 1024
# Epoch 2810/2900 : reward = 786, highest value = 256
# Epoch 2811/2900 : reward = 1423, highest value = 512
# Epoch 2812/2900 : reward = 1263, highest value = 512
# Epoch 2813/2900 : reward = 1093, highest value = 512
# Epoch 2814/2900 : reward = 822, highest value = 256
# Epoch 2815/2900 : reward = 619, highest value = 256
# Epoch 2816/2900 : reward = 1154, highest value = 512
# Epoch 2817/2900 : reward = 1267, highest value = 512
# Epoch 2818/2900 : reward = 402, highest value = 128
# Epoch 2819/2900 : reward = 587, highest value = 256
# Epoch 2820/2900 : reward = 416, highest value = 128
# Epoch 2821/2900 : reward = 436, highest value = 128
# Epoch 2822/2900 : reward = 385, highest value = 128
# Epoch 2823/2900 : reward = 571, highest value = 256
# Epoch 2824/2900 : reward = 2301, highest value = 1024
# Epoch 2825/2900 : reward = 2321, highest value = 1024
# Epoch 2826/2900 : reward = 727, highest value = 256
# Epoch 2827/2900 : reward = 584, highest value = 128
# Epoch 2828/2900 : reward = 646, highest value = 256
# Epoch 2829/2900 : reward = 730, highest value = 256
# Epoch 2830/2900 : reward = 627, highest value = 256
# Epoch 2831/2900 : reward = 1060, highest value = 512
# Epoch 2832/2900 : reward = 809, highest value = 256
# Epoch 2833/2900 : reward = 1590, highest value = 512
# Epoch 2834/2900 : reward = 366, highest value = 64
# Epoch 2835/2900 : reward = 822, highest value = 256
# Epoch 2836/2900 : reward = 1125, highest value = 512
# Epoch 2837/2900 : reward = 1023, highest value = 512
# Epoch 2838/2900 : reward = 599, highest value = 256
# Epoch 2839/2900 : reward = 633, highest value = 256
# Epoch 2840/2900 : reward = 738, highest value = 256
# Epoch 2841/2900 : reward = 1181, highest value = 512
# Epoch 2842/2900 : reward = 1407, highest value = 512
# Epoch 2843/2900 : reward = 299, highest value = 64
# Epoch 2844/2900 : reward = 590, highest value = 256
# Epoch 2845/2900 : reward = 793, highest value = 256
# Epoch 2846/2900 : reward = 1691, highest value = 512
# Epoch 2847/2900 : reward = 505, highest value = 256
# Epoch 2848/2900 : reward = 1496, highest value = 512
# Epoch 2849/2900 : reward = 858, highest value = 256
# Epoch 2850/2900 : reward = 1261, highest value = 512
# Epoch 2851/2900 : reward = 1004, highest value = 512
# Epoch 2852/2900 : reward = 577, highest value = 128
# Epoch 2853/2900 : reward = 1226, highest value = 512
# Epoch 2854/2900 : reward = 455, highest value = 128
# Epoch 2855/2900 : reward = 1054, highest value = 512
# Epoch 2856/2900 : reward = 504, highest value = 128
# Epoch 2857/2900 : reward = 1444, highest value = 1024
# Epoch 2858/2900 : reward = 1391, highest value = 512
# Epoch 2859/2900 : reward = 716, highest value = 256
# Epoch 2860/2900 : reward = 922, highest value = 512
# Epoch 2861/2900 : reward = 687, highest value = 256
# Epoch 2862/2900 : reward = 1909, highest value = 1024
# Epoch 2863/2900 : reward = 655, highest value = 256
# Epoch 2864/2900 : reward = 563, highest value = 128
# Epoch 2865/2900 : reward = 697, highest value = 256
# Epoch 2866/2900 : reward = 1042, highest value = 256
# Epoch 2867/2900 : reward = 1170, highest value = 512
# Epoch 2868/2900 : reward = 472, highest value = 128
# Epoch 2869/2900 : reward = 694, highest value = 256
# Epoch 2870/2900 : reward = 693, highest value = 256
# Epoch 2871/2900 : reward = 888, highest value = 512
# Epoch 2872/2900 : reward = 698, highest value = 256
# Epoch 2873/2900 : reward = 443, highest value = 128
# Epoch 2874/2900 : reward = 666, highest value = 256
# Epoch 2875/2900 : reward = 1024, highest value = 512
# Epoch 2876/2900 : reward = 680, highest value = 256
# Epoch 2877/2900 : reward = 403, highest value = 128
# Epoch 2878/2900 : reward = 689, highest value = 256
# Epoch 2879/2900 : reward = 719, highest value = 256
# Epoch 2880/2900 : reward = 582, highest value = 256
# Epoch 2881/2900 : reward = 617, highest value = 256
# Epoch 2882/2900 : reward = 1469, highest value = 512
# Epoch 2883/2900 : reward = 530, highest value = 128
# Epoch 2884/2900 : reward = 644, highest value = 256
# Epoch 2885/2900 : reward = 861, highest value = 512
# Epoch 2886/2900 : reward = 1326, highest value = 512
# Epoch 2887/2900 : reward = 578, highest value = 256
# Epoch 2888/2900 : reward = 1680, highest value = 1024
# Epoch 2889/2900 : reward = 753, highest value = 256
# Epoch 2890/2900 : reward = 590, highest value = 256
# Epoch 2891/2900 : reward = 821, highest value = 256
# Epoch 2892/2900 : reward = 576, highest value = 128
# Epoch 2893/2900 : reward = 776, highest value = 256
# Epoch 2894/2900 : reward = 856, highest value = 256
# Epoch 2895/2900 : reward = 913, highest value = 512
# Epoch 2896/2900 : reward = 799, highest value = 512
# Epoch 2897/2900 : reward = 1783, highest value = 1024
# Epoch 2898/2900 : reward = 1035, highest value = 512
# Epoch 2899/2900 : reward = 716, highest value = 256
# Epoch 2900/2900 : reward = 411, highest value = 128
# ----------------------------------------------------------------------
# Average of log2(high) while playing : 8.25
# Average of high while playing : 403.2
# ----------------------------------------------------------------------
# ____________________________________________________________________________________________________
# Training ended !
# ____________________________________________________________________________________________________
# Format :
#
# soft_bs=64_gamma=0.99_lr=0.0001_eps=0.2_decay=750
# Model saved !

# %% [markdown]
# ## Training results

# %%
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

def moving_median(x, w):
    return [np.median(x[i:i+w]) for i in range(len(x) - w)]

# %%
plt.plot(agent.train_high_history)

# %%
metric = agent.train_high_history
window_size = 100

plt.plot(moving_average(metric, window_size), label="Moving average")
plt.plot(moving_median(metric, window_size), label="Moving median")

plt.xlabel("Training games (episodes)")
plt.ylabel("Highest tile reached")

plt.title("Evolution of highest tile value during training")

plt.legend()

# %%
metric = agent.train_reward_history
window_size = 100

plt.plot(moving_average(metric, window_size), label="Moving average")
plt.plot(moving_median(metric, window_size), label="Moving median")

plt.xlabel("Training games (episodes)")
plt.ylabel("Cumulative reward")

plt.title("Evolution of cumulative reward during training")

plt.legend()

# %%
metric = agent.train_play_high_history
window_size = 10

plt.plot(moving_average(metric, window_size), label="Moving average")
plt.plot(moving_median(metric, window_size), label="Moving median")

plt.xlabel("Training games (episodes)")
plt.ylabel("Highest tile reached")

plt.title("Evolution of highest tile value during training (when the agent plays)")

plt.legend()

# %% [markdown]
# ## Playing and testing

# %% [markdown]
# We load the model that we just trained

# %%
path_format = "soft_bs=64_gamma=0.99_lr=0.0001_eps=0.2_decay=750"
agent.load_model(path_format)
# Out:
# Model loaded !

# %% [markdown]
# We will now play several games to examine the distribution of score of the agent.

# %%
from collections import defaultdict

play_high_dict = defaultdict(int)
occurences = []

n_plays_test = 1000

for _ in tqdm(range(n_plays_test)):
    agent.play(False)

    highest_value = agent.play_high

    occurences.append(highest_value)

    play_high_dict[highest_value] += 1
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 1000/1000 [24:49<00:00,  1.49s/it]

# %%
play_high_dict
# Out:
# defaultdict(int,
#             {512: 392, 256: 379, 64: 18, 1024: 114, 128: 94, 32: 2, 2048: 1})

# %%
plt.hist(occurences, align='mid', bins=50)

plt.xlabel('Highest reached values')
plt.ylabel('Frequency')

plt.title("Frequency of reached values after 1000 test runs")
#plt.xscale('log')
# Out:
# Text(0.5, 1.0, 'Frequency of reached values after 1000 test runs')

# %%
agent.play()
# Out:
# Score: 12196.0
# Highest: 1024
# [[   2   64    4    8]
#  [  16 1024    8  128]
#  [   4   16  256   32]
#  [   2   32    4    2]]

# %% [markdown]
# # Thank you !
